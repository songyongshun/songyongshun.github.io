# %% [markdown]
# # http.server构建服务器实现用户注册登录-练习题

# %% [markdown]
# ## 练习1：用http.server构建一个静态html网页服务器，注意self.path的内容。

# %%
from http.server import HTTPServer, SimpleHTTPRequestHandler

PORT = 8010

class CustomHandler(SimpleHTTPRequestHandler):
    def do_GET(self):
        if self.path == ??? :    # TODO: 修改路径判断,使其匹配 "/index.html"
            self.send_response(200)
            self.send_header("Content-type", "text/html; charset=utf-8")
            self.end_headers()
            html = '''
<!DOCTYPE html>
<html lang="zh-CN">
<head>
    <meta charset="UTF-8">
    <title>Hello</title>
</head>
<body>
    <h1>Hello, World!</h1>
    <p>注意要手动停止服务器代码块，再进行下一个练习</p>
</body>
</html>
'''
            self.wfile.write(html.encode("utf-8"))
        else:
            self.send_response(404)
            self.send_header("Content-type", "text/html; charset=utf-8")
            self.end_headers()
            self.wfile.write(b"404 Not Found")

with HTTPServer(("127.0.0.1", PORT), CustomHandler) as httpd:
    print(f"服务器运行中，访问 http://localhost:{PORT}/index.html")
    httpd.serve_forever()

# %% [markdown]
# ## 练习2：将html单独保存成一个页面，在主程序里引用，请自己在当前目录下创建'index.html'文件，并测试是否可以访问。
#
# index.html的内容，可以参考练习1的内容。

# %%
from http.server import HTTPServer, SimpleHTTPRequestHandler

PORT = 8010

class CustomHandler(SimpleHTTPRequestHandler):
    def do_GET(self):
        if self.path == ??? : # TODO: 修改路径判断,使其匹配 "/index.html"
            self.send_response(200)
            self.send_header("Content-type", "text/html; charset=utf-8")
            self.end_headers()
            html = open("???", "r", encoding="utf-8").read()  # TODO: 从 hello.html 文件中读取内容
            self.wfile.write(html.encode("utf-8"))
        else:
            self.send_response(404)
            self.send_header("Content-type", "text/html; charset=utf-8")
            self.end_headers()
            self.wfile.write(b"404 Not Found")

with HTTPServer(("127.0.0.1", PORT), CustomHandler) as httpd:
    print(f"服务器运行中，访问 http://localhost:{PORT}/index.html")
    httpd.serve_forever()

# %% [markdown]
# ## 练习3：构建api服务器，在主程序里引用json文件里的数据。
# 注意data.json需要你自己创建。
# 可参考写入的内容：
# ```
# {
#     name: "Li Ling",
#     age: 30,
#     occupation: "Software Developer"
# }
# ```
# 请测试，如果headers处的Content-type的内容，从application/json改为text/html，浏览器访问会有什么变化？

# %%
from http.server import HTTPServer, SimpleHTTPRequestHandler

PORT = 8010

class CustomHandler(SimpleHTTPRequestHandler):
    def do_GET(self):
        if self.path == ??? : # TODO: 修改路径判断,使其匹配 "/api"
            self.send_response(200)
            self.send_header("Content-type", "application/json; charset=utf-8")
            self.end_headers()
            html = open("???", "r", encoding="utf-8").read() # TODO: 从 data.json 文件中读取内容
            self.wfile.write(html.encode("utf-8"))
        else:
            self.send_response(404)
            self.send_header("Content-type", "text/html; charset=utf-8")
            self.end_headers()
            self.wfile.write(b"404 Not Found")

with HTTPServer(("127.0.0.1", PORT), CustomHandler) as httpd:
    print(f"服务器运行中，访问 http://localhost:{PORT}/api")
    httpd.serve_forever()

# %% [markdown]
# ## 练习4：构建用户注册页面，实现将用户信息写入`users.txt`文件里。
#
# 首先创建register.html页面，内容为
# ```
# <!DOCTYPE html>
# <html>
# <head>
#     <title>用户注册</title>
# </head>
# <body>
#     <h1>用户注册</h1>
#     <form action="/register" method="post">
#         <label for="username">用户名:</label>
#         <input type="text" id="username" name="username" required><br><br>
#         <label for="password">密码:</label>
#         <input type="password" id="password" name="password" required><br><br>
#         <button type="submit">注册</button>
#     </form>
# </body>
# </html>
# ```
# 注意这里使用了html的form表单，用户可以在表单上向服务器发起post请求。
#
# post请求会转向一个新的URL，一般无后缀名。
#
# users.txt文件里如果手动添加用户名和密码，注意末尾要加回车。

# %%
from http.server import HTTPServer, SimpleHTTPRequestHandler
from urllib.parse import parse_qs 

PORT = 8020

class CustomHandler(SimpleHTTPRequestHandler):
    def do_GET(self):
        if self.path == ??? : # TODO: 修改路径判断,使其匹配 "/register.html"
            self.send_response(200)
            self.send_header("Content-type", "text/html; charset=utf-8")
            self.end_headers()
            jsondata = open("???", "r", encoding="utf-8").read() # TODO: 从 register.html 文件中读取内容
            self.wfile.write(jsondata.encode("utf-8"))
        else:
            self.send_response(404)
            self.send_header("Content-type", "text/html; charset=utf-8")
            self.end_headers()
            self.wfile.write(b"404 Not Found")
    def do_POST(self):  
        # 处理注册表单提交  
        if self.path == "/register":  
            content_length = int(self.headers["Content-Length"])  
            post_data = self.rfile.read(content_length).decode("utf-8")  
            form_data = parse_qs(???)  # TODO: 解析表单数据
  
            username = form_data.get("username", [""])[0]  
            password = form_data.get("password", [""])[0]  

            # 简单存储到文件
            with open("users.txt", "a") as f:  
                f.write(f"{username},{password}\n")  
  
            # 返回成功响应  
            self.send_response(200)  
            self.send_header("Content-type", "text/html; charset=utf-8")  
            self.end_headers()  
            self.wfile.write("<h1>注册成功！</h1><a href='/register.html'>返回</a>".encode("utf-8"))

with HTTPServer(("127.0.0.1", PORT), CustomHandler) as httpd:
    print(f"服务器运行中，访问 http://localhost:{PORT}/register.html")
    httpd.serve_forever()

# %% [markdown]
# ## 练习5：为注册页面添加用户名是否已经存在功能

# %%
from http.server import HTTPServer, SimpleHTTPRequestHandler
from urllib.parse import parse_qs 

PORT = 8020

class CustomHandler(SimpleHTTPRequestHandler):
    def do_GET(self):
        if self.path == "???": # TODO: 修改路径判断,使其匹配 "/register.html"
            self.send_response(200)
            self.send_header("Content-type", "text/html; charset=utf-8")
            self.end_headers()
            jsondata = open("register.html", "r", encoding="utf-8").read()
            self.wfile.write(jsondata.encode("utf-8"))
        else:
            self.send_response(404)
            self.send_header("Content-type", "text/html; charset=utf-8")
            self.end_headers()
            self.wfile.write(b"404 Not Found")
    def do_POST(self):  
        # 处理注册表单提交  
        if self.path == "/register":  
            content_length = int(self.headers["Content-Length"])  
            post_data = self.rfile.read(content_length).decode("utf-8")  
            form_data = parse_qs(post_data)  

            username = form_data.get("username", [""])[0]  
            password = form_data.get("password", [""])[0]  

            # 检查用户名是否已存在
            with open("users.txt", "r") as f:  
                users = f.readlines()  
            existing_usernames = [line.strip().split(",")[0] for line in users]

            if username in ??? : # TODO: 检查用户名是否已存在
                self.send_response(400)  
                self.send_header("Content-type", "text/html; charset=utf-8")  
                self.end_headers()  
                self.wfile.write("<h1>用户名已存在！</h1><a href='/register.html'>返回注册页面</a>".encode("utf-8"))
                return
                
            # 简单存储到文件
            with open("users.txt", "a") as f:  
                f.write(f"{username},{password}\n")  
            # 返回成功响应  
            self.send_response(200)  
            self.send_header("Content-type", "text/html; charset=utf-8")  
            self.end_headers()  
            self.wfile.write("<h1>注册成功！</h1><a href='/login.html'>登录</a>".encode("utf-8"))

with HTTPServer(("127.0.0.1", PORT), CustomHandler) as httpd:
    print(f"服务器运行中，访问 http://localhost:{PORT}/register.html")
    httpd.serve_forever()

# %% [markdown]
# ## 练习6： 添加用户登录页面，将用户输入的登录信息与`users.txt`信息进行比对，如果存在且密码正确，跳转到登录成功页面。

# %%
from http.server import HTTPServer, SimpleHTTPRequestHandler
from urllib.parse import parse_qs 

PORT = 8020

class CustomHandler(SimpleHTTPRequestHandler):
    def do_GET(self):
        if self.path == "/register.html":
            self.send_response(200)
            self.send_header("Content-type", "text/html; charset=utf-8")
            self.end_headers()
            jsondata = open("register.html", "r", encoding="utf-8").read()
            self.wfile.write(jsondata.encode("utf-8"))
        elif self.path == "???":  # TODO: 修改路径判断,使其匹配 "/login.html"
            self.send_response(200)
            self.send_header("Content-type", "text/html; charset=utf-8")
            self.end_headers()
            jsondata = open("login.html", "r", encoding="utf-8").read()
            self.wfile.write(jsondata.encode("utf-8"))
        else:
            self.send_response(404)
            self.send_header("Content-type", "text/html; charset=utf-8")
            self.end_headers()
            self.wfile.write(b"404 Not Found")
    def do_POST(self):  
        # 处理注册表单提交  
        if self.path == "/register":  
            content_length = int(self.headers["Content-Length"])  
            post_data = self.rfile.read(content_length).decode("utf-8")  
            form_data = parse_qs(post_data)  

            username = form_data.get("username", [""])[0]  
            password = form_data.get("password", [""])[0]  

            # 检查用户名是否已存在
            with open("users.txt", "r") as f:  
                users = f.readlines()  
            existing_usernames = [line.strip().split(",")[0] for line in users]

            if username in existing_usernames:
                self.send_response(400)  
                self.send_header("Content-type", "text/html; charset=utf-8")  
                self.end_headers()  
                self.wfile.write("<h1>用户名已存在！</h1><a href='/register.html'>返回注册页面</a>".encode("utf-8"))
                return

            # 简单存储到文件（实际项目应使用数据库）  
            with open("users.txt", "a") as f:  
                f.write(f"{username},{password}\n")  
            # 返回成功响应  
            self.send_response(200)  
            self.send_header("Content-type", "text/html; charset=utf-8")  
            self.end_headers()  
            self.wfile.write("<h1>注册成功！</h1><a href='/login.html'>登录</a>".encode("utf-8"))
        elif self.path == "/login": 
            content_length = int(self.headers["Content-Length"])  
            post_data = self.rfile.read(content_length).decode("utf-8")  
            form_data = parse_qs(???)  # TODO : 解析表单数据
  
            username = form_data.get("username", [""])[0]  
            password = form_data.get("password", [""])[0]  
  
            # 验证用户  
            with open("users.txt", "r") as f:  
                users = f.readlines()  
  
            user_found = any(line.strip() == f"{username},{password}" for line in users)  
  
            if user_found:  
                self.send_response(200)  
                self.send_header("Content-type", "text/html; charset=utf-8")  
                self.end_headers()  
                self.wfile.write("<h1>登录成功！</h1><a href='/login.html'>返回</a>".encode("utf-8"))  
            else:  
                self.send_response(401)  
                self.send_header("Content-type", "text/html; charset=utf-8")  
                self.end_headers()  
                self.wfile.write("<h1>登录失败，用户名或密码错误！</h1><a href='/login.html'>返回</a>".encode("utf-8"))

with HTTPServer(("127.0.0.1", PORT), CustomHandler) as httpd:
    print(f"服务器运行中，访问 http://localhost:{PORT}/login.html")
    httpd.serve_forever()

# %% [markdown]
# ## 练习7：重构do_GET，使得URL指向任意html页面，都可以正确定向到当前文件夹下的html文件。
#
# 注意self.path是字符串

# %%
from http.server import HTTPServer, SimpleHTTPRequestHandler
from urllib.parse import parse_qs 

PORT = 8020

class CustomHandler(SimpleHTTPRequestHandler):
    def do_GET(self):
        if self.path.endswith(".html"):
            try:
                filename = self.path[1:]  # Remove leading '/'
                with open(???, "r", encoding="utf-8") as f:  # TODO, 打开对应的html文件
                    content = f.read()
                self.send_response(200)
                self.send_header("Content-type", "text/html; charset=utf-8")
                self.end_headers()
                self.wfile.write(content.encode("utf-8"))
            except FileNotFoundError:
                self.send_response(404)
                self.send_header("Content-type", "text/html; charset=utf-8")
                self.end_headers()
                self.wfile.write(b"404 Not Found")
        else:
            self.send_response(404)
            self.send_header("Content-type", "text/html; charset=utf-8")
            self.end_headers()
            self.wfile.write(b"404 Not Found")
    def do_POST(self):  
        # 处理注册表单提交  
        if self.path == "/register":  
            content_length = int(self.headers["Content-Length"])  
            post_data = self.rfile.read(content_length).decode("utf-8")  
            form_data = parse_qs(post_data)  

            username = form_data.get("username", [""])[0]  
            password = form_data.get("password", [""])[0]  

            # 检查用户名是否已存在
            with open("users.txt", "r") as f:  
                users = f.readlines()  
            existing_usernames = [line.strip().split(",")[0] for line in users]

            if username in existing_usernames:
                self.send_response(400)  
                self.send_header("Content-type", "text/html; charset=utf-8")  
                self.end_headers()  
                self.wfile.write("<h1>用户名已存在！</h1><a href='/register.html'>返回注册页面</a>".encode("utf-8"))
                return

            # 简单存储到文件（实际项目应使用数据库）  
            with open("users.txt", "a") as f:  
                f.write(f"{username},{password}\n")  
            # 返回成功响应  
            self.send_response(200)  
            self.send_header("Content-type", "text/html; charset=utf-8")  
            self.end_headers()  
            self.wfile.write("<h1>注册成功！</h1><a href='/login.html'>登录</a>".encode("utf-8"))
        elif self.path == "/login": 
            content_length = int(self.headers["Content-Length"])  
            post_data = self.rfile.read(content_length).decode("utf-8")  
            form_data = parse_qs(???)  # TODO : 解析表单数据
  
            username = form_data.get("username", [""])[0]  
            password = form_data.get("password", [""])[0]  
  
            # 验证用户  
            with open("users.txt", "r") as f:  
                users = f.readlines()  
  
            user_found = any(line.strip() == f"{username},{password}" for line in users)  
  
            if user_found:  
                self.send_response(200)  
                self.send_header("Content-type", "text/html; charset=utf-8")  
                self.end_headers()  
                self.wfile.write("<h1>登录成功！</h1><a href='/login.html'>返回</a>".encode("utf-8"))  
            else:  
                self.send_response(401)  
                self.send_header("Content-type", "text/html; charset=utf-8")  
                self.end_headers()  
                self.wfile.write("<h1>登录失败，用户名或密码错误！</h1><a href='/login.html'>返回</a>".encode("utf-8"))

with HTTPServer(("127.0.0.1", PORT), CustomHandler) as httpd:
    print(f"服务器运行中，访问 http://localhost:{PORT}/login.html")
    httpd.serve_forever()

# %% [markdown]
# ## 练习8：添加存储用户数据功能，不同用户的数据存储在./data/{username}/下，当登录成功后，不是仅仅跳转到同一个页面。而是会检查用户目录是否存在，如果不存在，创建用户目录，并跳转到./data/{username}/user-input.html页面。
#
# 注意，不同用户的./data/{username}/user-input.html页面是不同的，所以需要动态生成，因此放到主程序里。
#
# user-input.html页面的内容为一个输入框和保存按钮，保存按钮可发送POST请求，将数据存储在用户目录下。
#
# os模块用户实现用户目录的创建，不过，仍需要你**手动创建./data目录**。
#
# 提交数据后，请检查用户目录下是否多了文件`last_content.txt`，并检查里面的内容是否为刚输入的内容。

# %%
from http.server import HTTPServer, SimpleHTTPRequestHandler
from urllib.parse import parse_qs 
import os

PORT = 8020

class CustomHandler(SimpleHTTPRequestHandler):
    def do_GET(self):
        # 处理 /data/<username>/user-input.html 动态页面
        if self.path.startswith("/data/") and self.path.endswith("/user-input.html"):
            parts = self.path.split("/")
            if len(???) >= 4:  # TODO : 确保路径格式正确
                username = parts[2]  # /data/username/user-input.html → parts[2] = username
                self.send_response(200)
                self.send_header("Content-type", "text/html; charset=utf-8")
                self.end_headers()
                html_content = f'''
<!DOCTYPE html>
<html lang="zh-CN">
<head>
    <meta charset="UTF-8">
    <title>用户输入</title>
</head>
<body>
    <h2>当前用户: {username}</h2>
    <form action="/save" method="post">
        <label for="user-input">请输入内容:</label><br>
        <input type="text" id="user-input" name="user-input" required><br><br>
        <input type="hidden" name="username" value="{username}">
        <button type="submit">保存</button>
    </form>
</body>
</html>
                '''
                self.wfile.write(html_content.encode("utf-8"))
            else:
                self.send_response(400)
                self.end_headers()
                self.wfile.write(b"Invalid path")
        elif self.path.endswith(".html"):
            try:
                filename = self.path[1:]  # Remove leading '/'
                with open(filename, "r", encoding="utf-8") as f:
                    content = f.read()
                self.send_response(200)
                self.send_header("Content-type", "text/html; charset=utf-8")
                self.end_headers()
                self.wfile.write(content.encode("utf-8"))
            except FileNotFoundError:
                self.send_response(404)
                self.send_header("Content-type", "text/html; charset=utf-8")
                self.end_headers()
                self.wfile.write(b"404 Not Found")
        else:
            self.send_response(404)
            self.send_header("Content-type", "text/html; charset=utf-8")
            self.end_headers()
            self.wfile.write(b"404 Not Found")
    def do_POST(self):  
        # 处理注册表单提交  
        if self.path == "/register":  
            content_length = int(self.headers["Content-Length"])  
            post_data = self.rfile.read(content_length).decode("utf-8")  
            form_data = parse_qs(post_data)  

            username = form_data.get("username", [""])[0]  
            password = form_data.get("password", [""])[0]  

            # 检查用户名是否已存在

            with open("users.txt", "r") as f:  
                users = f.readlines()  
            existing_usernames = [line.strip().split(",")[0] for line in users]

            if username in existing_usernames:
                self.send_response(400)  
                self.send_header("Content-type", "text/html; charset=utf-8")  
                self.end_headers()  
                self.wfile.write("<h1>用户名已存在！</h1><a href='/register.html'>返回注册页面</a>".encode("utf-8"))
                return

            # 简单存储到文件
            with open("users.txt", "a") as f:  
                f.write(f"{username},{password}\n")  
            # 返回成功响应  
            self.send_response(200)  
            self.send_header("Content-type", "text/html; charset=utf-8")  
            self.end_headers()  
            self.wfile.write("<h1>注册成功！</h1><a href='/login.html'>登录</a>".encode("utf-8"))
        elif self.path == "/login": 
            content_length = int(self.headers["Content-Length"])  
            post_data = self.rfile.read(content_length).decode("utf-8")  
            form_data = parse_qs(post_data)  
  
            username = form_data.get("username", [""])[0]  
            password = form_data.get("password", [""])[0]  
  
            # 验证用户  
            with open("users.txt", "r") as f:  
                users = f.readlines()  
  
            user_found = any(line.strip() == f"{username},{password}" for line in users)  
  
            if user_found:  
                # 创建用户数据目录（如果不存在）
                user_dir = os.path.join("data", username)
                os.makedirs(user_dir, exist_ok=True)

                self.send_response(200)  
                self.send_header("Content-type", "text/html; charset=utf-8")  
                self.end_headers()  
                redirect_url = f"/data/{username}/user-input.html"
                self.wfile.write(f"<h1>登录成功！</h1><a href='{redirect_url}'>进入用户页面</a>".encode("utf-8"))  
            else:  
                self.send_response(401)  
                self.send_header("Content-type", "text/html; charset=utf-8")  
                self.end_headers()  
                self.wfile.write("<h1>登录失败，用户名或密码错误！</h1><a href='/login.html'>返回</a>".encode("utf-8"))
        elif self.path == "/save":
            content_length = int(self.headers["Content-Length"])
            post_data = self.rfile.read(content_length).decode("utf-8")
            form_data = parse_qs(???)  # TODO : 解析表单数据

            username = form_data.get("username", [""])[0]
            user_input = form_data.get("user-input", [""])[0]

            user_dir = os.path.join("data", username)

            # 保存内容到 last_content.txt
            content_file = os.path.join(user_dir, "last_content.txt")
            with open(???, "w", encoding="utf-8") as f:  ## TODO : 打开对应的文件
                f.write(user_input)

            self.send_response(200)
            self.send_header("Content-type", "text/html; charset=utf-8")
            self.end_headers()
            self.wfile.write(f"<h1>保存成功！</h1><a href='/data/{username}/user-input.html'>返回</a>".encode("utf-8"))

with HTTPServer(("127.0.0.1", PORT), CustomHandler) as httpd:
    print(f"服务器运行中，访问 http://localhost:{PORT}/login.html")
    httpd.serve_forever()
